# %%
import matplotlib.pyplot as plt
import numpy as np
company=['a','b','c','d']
ypos=np.arange(len(company))
rev=[14,235,23,56]
plt.xticks(ypos,company)
plt.bar(ypos,rev,label='marks')
plt.legend()
plt.show()
x=np.arange(15);
bs_women=[32,672,33,656,34,5,34,65,87,23,97,43,65,76,98]
bs_men=[90,10,40,43,65,34,76,23,287,32,672,33,656,34,545]
plt.barh(x+0.2,bs_men,linewidth=0.7,edgecolor='red',color='yellow',ecolor='blue')
plt.barh(x,bs_women,linewidth=0.9,edgecolor='red',color='cyan')
# Out:
# <BarContainer object of 15 artists>
