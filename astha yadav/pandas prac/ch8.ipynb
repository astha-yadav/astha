# %%
#pulling data from microsoft sql database
import pandas as pd
from sqlalchemy import create_engine,MetaData,Table,select, engine

# %%
#Version 1-servername,database,tablename-own
tablename="data"
DB={
    'drivername':'mssql+pyodbc',
    'servername':'ABS',
    #'port':'5432',
    #'username':'lynn',
    #'password':'',
    'database':'BizIntel',
    'driver':'SQL Server Native Client 11.0',
    'trusted_connection':'yes',
    'legacy_schema_aliasing':False
}

#create connection
engine=create_engine(DB['drivername']+'://'+DB['servername']+'/'+DB['database']+'?'+DB['driver']+';'+'trusted_connection=' + DB['trusted_connection'], legacy_schema_aliasing=DB['legacy_schema_aliasing'])
conn=engine.connect()

#reqd for querying tables
metadata=MetaData(conn)

#table to query
tbl=Table(TableName,metadata, autoload=True,schema="dbo")

#select all
sql=tbl.select()
#run sql code
result=conn.execute(sql)

#insert to a dataframe
df=pd.DataFrame(data=list(result), columns=result.keys())

#close connection
conn.close()
print('Done')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sqlalchemy\connectors\pyodbc.py:79: SAWarning: No driver name specified; this is expected by PyODBC when using DSN-less connections
#   "No driver name specified; "
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     341         """
# --> 342         return _ConnectionFairy._checkout(self)
#     343
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ...

# %%
#version 2
import pandas.io.sql
import pyodbc

#parameters
server='DAVID-THINK'
db='BizIntel'

#create the connection
conn=pyodbc.connect('DRIVER={SQL Server}; SERVER='+ DB['servername'] + ';DATABASE=' + DB['database'] + ';Trusted_Connection=yes')

#query db
sql="""
SELECT top 5 *
FROM data
"""
df=pandas.io.sql.read_sql(sql, conn)
df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-20937324dcfb> in <module>
#       8
#       9 #create the connection
# ---> 10 conn=pyodbc.connect('DRIVER={SQL Server}; SERVER='+ DB['servername'] + ';DATABASE=' + DB['database'] + ';Trusted_Connection=yes')
#      11
#      12 #query db
#
# OperationalError: ('08001', '[08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]SQL Server does not exist or access denied. (17) (SQLDriverConnect); [08001] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionOpen (Connect()). (53)')

# %%
#version 3
from sqlalchemy from create_engine

#parameters
ServerName="ACB"
Database="BizIntel"
Driver="driver=SQL Server Native Client 11.0"

#create the connection
engine = create_engine('mssql+pyodbc://' + ServerName + '/' + Database + "?" + Driver)
df=pd.read_sql_query("SELECT top 5 * FROM data",engine)
df
# Out:
#   File "<ipython-input-4-9973eb0d1105>", line 2
#     from sqlalchemy from create_engine
#                        ^
# SyntaxError: invalid syntax
