# %%
import matplotlib.pyplot as plt
import numpy as np
bs_women=[32,672,33,656,34,5,34,65,87,23,97,43,65,76,98,32,65]
bs_men=[90,10,40,43,65,34,76,23,287,32,672,33,656,34,545]
plt.hist([bs_women,bs_men],bins=10,range=(0,150),rwidth=0.8,log=True,color=['g','k'],density=True,edgecolor='red',stacked=True,histtype='bar',align='right',label=['women','men'],orientation='vertical')
plt.legend()
plt.xlabel('blood sugar')
plt.ylabel('no of people')
plt.show()
