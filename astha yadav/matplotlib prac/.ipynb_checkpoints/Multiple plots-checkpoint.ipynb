# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,5)
y=x**3
plt.figure()
plt.subplot(411,title='fig a',frame_on=True,alpha=0.1,xlabel='aaa',adjustable='box',facecolor='cyan',autoscale_on=True)
plt.plot(x,y)
plt.subplot(412,title='fig a',frame_on=True,alpha=0.1,xlabel='aaa',adjustable='box',facecolor='cyan',autoscale_on=True)
plt.plot(x,y**4)
plt.subplot(413,title='fig a',frame_on=True,alpha=0.1,xlabel='aaa',adjustable='box',facecolor='cyan',autoscale_on=True)
plt.plot(x,y**3)
plt.subplot(414)
plt.plot(x,y**6)
