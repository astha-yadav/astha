# %%
import matplotlib.pyplot as plt
import numpy as np

names=['pie','rajma','maggie','pasta','all']
people=[400,879,679,986,467]
plt.pie(people,labels=names,shadow=True,explode=[0,0,0.25,0.1,0],radius=1.5,startangle=90,frame=True,autopct='%0.1f%%',rotatelabels=True)
plt.show()
